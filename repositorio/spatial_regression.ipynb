# %%
from __future__ import division
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import pysal as ps
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
from shapely.geometry import Point
from sklearn import neighbors

sns.set(style="white")
sns.set_context({"figure.figsize": (24, 10)})

pd.options.display.float_format = '{:.2f}'.format

abb_link = './tfg/dbases/development3.csv'
zc_link = './tfg/mapas/barrios_area.shp'

muestra = pd.read_csv(abb_link)
barrios = gpd.read_file(zc_link)

geometry = [Point(xy) for xy in zip(muestra['lon'], muestra['lat'])]
crs = {'init': 'epsg:4326'}
geo_df = GeoDataFrame(muestra, crs=crs, geometry=geometry)

db = gpd.sjoin(geo_df, barrios, how="inner", op='intersects')

metro = pd.read_csv('./tfg/dbases/distance_matrix_metro.csv')

db = db.join(metro.set_index('InputID'),
                            on='id', how='left')

db = db.rename(index=str, columns={"DESBDT": "subdistrict_f", "Distance": "metro_distance", "NUMPOINTS": "metro_number"})

db = pd.DataFrame(db)
db['floor']=db['floor'].replace(['Ground floor', 'Mezzanine', 'Semi-basement', 'Basement', 'ground', 'Floor -2', 'Floor -1'], 0,regex=True)
#db.replace(u'\xe', 'A')
db['floor'] = pd.to_numeric(db['floor'])

# %%
varis = ['pricems', 'rooms', 'floor', 'needs_renovating', 'garden', 'terrace', 'new_dev', 'garage']

# %%
zona = dict()
mcl = dict()
mscl = dict()

# %%
for clu in range(0, 8):
    
    zona[clu] = db[(db["cl"] == clu) & (db["share_loc"] == 1)].drop_duplicates(subset=["lat", "lon"] )
    y = np.log(zona[clu]['pricems'])
    yxs = zona[clu].loc[:, varis + ['pricems']].dropna()
    
    w = ps.knnW_from_array(zona[clu].loc[\
                               yxs.index, \
                              ['lon', 'lat']\
                              ].values)
    w.transform = 'R'
    
    mcl[clu] = ps.spreg.GM_Lag(y.values[:, None], yxs.drop('pricems', axis=1).values, \
                  w=w, spat_diag=True, \
                  name_x=yxs.drop('pricems', axis=1).columns.tolist(), name_y='ln(pricems)', \
                  name_ds = 'zona ' + str([clu]))
    
    mscl[clu] = mse(y, mcl[clu].predy.flatten())
    
    print(mcl[clu].summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [0]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         715
# Mean dependent var  :      7.9761                Number of Variables   :           7
# S.D. dependent var  :      0.3347                Degrees of Freedom    :         708
# Pseudo R-squared    :      0.4576
# Spatial Pseudo R-squared:  0.1492
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       4.0711675       0.7416391       5.4894190       0.0000000
#                floor       0.0070630       0.0031433       2.2470083       0.0246395
#     needs_renovating      -0.1143547       0.0279152      -4.0965033       0.0000419
#               garden       0.0770812       0.0238211       3.2358362       0.0012129
#              terrace      -0.0442073       0.0199171      -2.2195660       0.0264482
#               garage       0.1035933       0.0263351       3.9336546       0.0000837
#        W_ln(pricems)       0.4855870       0.0938388       5.1746941       0.0000002
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.069          0.7933
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [1]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         907
# Mean dependent var  :      8.2013                Number of Variables   :           7
# S.D. dependent var  :      0.2631                Degrees of Freedom    :         900
# Pseudo R-squared    :      0.1830
# Spatial Pseudo R-squared:  0.1114
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       7.0603319       0.9069544       7.7846600       0.0000000
#                floor       0.0151323       0.0029128       5.1951826       0.0000002
#     needs_renovating      -0.1622809       0.0219164      -7.4045507       0.0000000
#               garden       0.0098034       0.0200125       0.4898675       0.6242277
#              terrace      -0.0626607       0.0167819      -3.7338173       0.0001886
#               garage       0.0501001       0.0202216       2.4775499       0.0132288
#        W_ln(pricems)       0.1370575       0.1108079       1.2368933       0.2161267
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           2.173          0.1404
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [2]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:        1064
# Mean dependent var  :      7.6169                Number of Variables   :           7
# S.D. dependent var  :      0.3252                Degrees of Freedom    :        1057
# Pseudo R-squared    :      0.3498
# Spatial Pseudo R-squared:  0.2964
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       6.0456118       0.5328429      11.3459564       0.0000000
#                floor       0.0159098       0.0036305       4.3823046       0.0000117
#     needs_renovating      -0.2971784       0.0294275     -10.0986504       0.0000000
#               garden       0.0911145       0.0213583       4.2659969       0.0000199
#              terrace      -0.0752224       0.0165262      -4.5516992       0.0000053
#               garage       0.1333542       0.0216379       6.1630016       0.0000000
#        W_ln(pricems)       0.1963083       0.0709526       2.7667516       0.0056618
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.684          0.4083
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [3]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         740
# Mean dependent var  :      7.7027                Number of Variables   :           7
# S.D. dependent var  :      0.3136                Degrees of Freedom    :         733
# Pseudo R-squared    :      0.3708
# Spatial Pseudo R-squared:  0.2959
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       5.4169571       0.5488315       9.8699817       0.0000000
#                floor       0.0115250       0.0041533       2.7748971       0.0055219
#     needs_renovating      -0.2448012       0.0298458      -8.2021921       0.0000000
#               garden       0.0917426       0.0239575       3.8293833       0.0001285
#              terrace      -0.0289080       0.0186621      -1.5490177       0.1213775
#               garage       0.1669756       0.0260417       6.4118628       0.0000000
#        W_ln(pricems)       0.2883336       0.0721307       3.9973740       0.0000640
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.070          0.7916
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [4]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         661
# Mean dependent var  :      7.4571                Number of Variables   :           7
# S.D. dependent var  :      0.3151                Degrees of Freedom    :         654
# Pseudo R-squared    :      0.2923
# Spatial Pseudo R-squared:  0.2717
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       5.3444705       0.6489146       8.2360151       0.0000000
#                floor       0.0078087       0.0044882       1.7398214       0.0818904
#     needs_renovating      -0.2460237       0.0392503      -6.2680697       0.0000000
#               garden       0.1148447       0.0249135       4.6097373       0.0000040
#              terrace      -0.0683324       0.0213482      -3.2008476       0.0013702
#               garage       0.1237196       0.0281695       4.3919669       0.0000112
#        W_ln(pricems)       0.2769832       0.0878239       3.1538475       0.0016113
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           2.910          0.0880
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [5]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         814
# Mean dependent var  :      7.9485                Number of Variables   :           7
# S.D. dependent var  :      0.2893                Degrees of Freedom    :         807
# Pseudo R-squared    :      0.4109
# Spatial Pseudo R-squared:  0.3360
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       5.9857520       0.5547331      10.7903279       0.0000000
#                floor       0.0186573       0.0029537       6.3165871       0.0000000
#     needs_renovating      -0.2019659       0.0267524      -7.5494403       0.0000000
#               garden       0.0741883       0.0202027       3.6721903       0.0002405
#              terrace      -0.0416019       0.0164287      -2.5322711       0.0113326
#               garage       0.1553990       0.0194380       7.9945808       0.0000000
#        W_ln(pricems)       0.2310307       0.0707267       3.2665264       0.0010888
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.844          0.3582
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [6]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         561
# Mean dependent var  :      8.3250                Number of Variables   :           7
# S.D. dependent var  :      0.2694                Degrees of Freedom    :         554
# Pseudo R-squared    :      0.2824
# Spatial Pseudo R-squared:  0.1493
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       6.1737126       1.1888262       5.1931164       0.0000002
#                floor       0.0279786       0.0040982       6.8270260       0.0000000
#     needs_renovating      -0.1539418       0.0251243      -6.1272159       0.0000000
#               garden      -0.0320548       0.0347094      -0.9235199       0.3557363
#              terrace      -0.0041075       0.0214344      -0.1916307       0.8480315
#               garage       0.0870222       0.0297253       2.9275441       0.0034165
#        W_ln(pricems)       0.2516060       0.1429955       1.7595382       0.0784861
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.601          0.4381
# ================================ END OF REPORT =====================================
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :    zona [7]
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:         211
# Mean dependent var  :      8.5397                Number of Variables   :           7
# S.D. dependent var  :      0.2953                Degrees of Freedom    :         204
# Pseudo R-squared    :      0.3961
# Spatial Pseudo R-squared:  0.1144
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       4.7084127       1.2149534       3.8753854       0.0001065
#                floor       0.0169679       0.0069835       2.4297022       0.0151112
#     needs_renovating      -0.1254615       0.0411721      -3.0472452       0.0023095
#               garden      -0.0497977       0.0576031      -0.8644965       0.3873152
#              terrace      -0.0462607       0.0372546      -1.2417457       0.2143304
#               garage       0.1226929       0.0403178       3.0431431       0.0023412
#        W_ln(pricems)       0.4443209       0.1418758       3.1317602       0.0017376
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           0.023          0.8792
# ================================ END OF REPORT =====================================

# %% [markdown]
# Endogena

# %%
zona = db[(db["share_loc"] == 1)].drop_duplicates(subset=["lat", "lon"] )
y = np.log(zona['pricems'])
yxs = zona.loc[:, varis + ['pricems']].dropna()

w = ps.knnW_from_array(zona.loc[\
                           yxs.index, \
                          ['lon', 'lat']\
                          ].values)
w.transform = 'R'

mreg = ps.spreg.GM_Lag(y.values[:, None], yxs.drop('pricems', axis=1).values, \
              w=w, spat_diag=True, \
              name_x=yxs.drop('pricems', axis=1).columns.tolist(), name_y='ln(pricems)', \
              name_ds = 'madrid')

print(mreg.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      madrid
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:        5673
# Mean dependent var  :      7.9001                Number of Variables   :           7
# S.D. dependent var  :      0.4282                Degrees of Freedom    :        5666
# Pseudo R-squared    :      0.5786
# Spatial Pseudo R-squared:  0.0725
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       4.1645780       0.3229571      12.8951421       0.0000000
#                floor       0.0173748       0.0016446      10.5650279       0.0000000
#     needs_renovating      -0.1306761       0.0128406     -10.1768110       0.0000000
#               garden       0.0100313       0.0097241       1.0315896       0.3022644
#              terrace      -0.0737739       0.0088179      -8.3664018       0.0000000
#               garage       0.0998646       0.0106632       9.3653846       0.0000000
#        W_ln(pricems)       0.4679948       0.0411728      11.3665974       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_garden, W_needs_renovating, W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           7.558          0.0060
# ================================ END OF REPORT =====================================

# %%
varis = ['pricems', 'rooms', 'floor', 'needs_renovating', 'terrace', 'new_dev', 'garage']

zona = db[(db["share_loc"] == 1)].drop_duplicates(subset=["lat", "lon"] )
y = np.log(zona['pricems'])
yxs = zona.loc[:, varis + ['pricems']].dropna()

w = ps.knnW_from_array(zona.loc[\
                           yxs.index, \
                          ['lon', 'lat']\
                          ].values)
w.transform = 'R'

mreg = ps.spreg.GM_Lag(y.values[:, None], yxs.drop('pricems', axis=1).values, \
              w=w, spat_diag=True, \
              name_x=yxs.drop('pricems', axis=1).columns.tolist(), name_y='ln(pricems)', \
              name_ds = 'madrid')

print(mreg.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      madrid
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:        5673
# Mean dependent var  :      7.9001                Number of Variables   :           8
# S.D. dependent var  :      0.4282                Degrees of Freedom    :        5665
# Pseudo R-squared    :      0.5868
# Spatial Pseudo R-squared:  0.0665
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       4.0317772       0.3117614      12.9322510       0.0000000
#                rooms      -0.0154038       0.0036961      -4.1675557       0.0000308
#                floor       0.0178522       0.0016146      11.0569013       0.0000000
#     needs_renovating      -0.1207915       0.0127211      -9.4953408       0.0000000
#              terrace      -0.0657950       0.0089149      -7.3803017       0.0000000
#              new_dev       0.0778809       0.0351189       2.2176308       0.0265800
#               garage       0.1034185       0.0095790      10.7963756       0.0000000
#        W_ln(pricems)       0.4894892       0.0399764      12.2444403       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_ln(pricems)
# Instruments: W_floor, W_garage, W_needs_renovating, W_new_dev, W_rooms,
#              W_terrace
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Anselin-Kelejian Test             1           6.291          0.0121
# ================================ END OF REPORT =====================================

# %% [markdown]
# Regresores

# %%
varis = ['pricems', 'rooms', 'floor', 'needs_renovating', 'garden', 'terrace', 'new_dev', 'garage']

zona = db[(db["share_loc"] == 1)].drop_duplicates(subset=["lat", "lon"] )
y = np.log(zona['pricems'])
yxs = zona.loc[:, varis + ['pricems']].dropna()
w_garden = ps.knnW_from_array(zona.loc[\
                               yxs.index, \
                              ['lon', 'lat']\
                              ].values)
yxs_w = yxs.assign(w_garden=ps.lag_spatial(w_garden, yxs['garden'].values))

# %%
m2 = ps.spreg.OLS(y.values[:, None], \
                  yxs_w.drop('pricems', axis=1).values, \
                  w=w, spat_diag=True, \
                  name_x=yxs_w.drop('pricems', axis=1).columns.tolist(), name_y='ln(pricems)', name_ds = 'madrid')
print(m2.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :      madrid
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:        5673
# Mean dependent var  :      7.9001                Number of Variables   :           9
# S.D. dependent var  :      0.4282                Degrees of Freedom    :        5664
# R-squared           :      0.0795
# Adjusted R-squared  :      0.0782
# Sum squared residual:     957.433                F-statistic           :     61.1423
# Sigma-square        :       0.169                Prob(F-statistic)     :   2.563e-96
# S.E. of regression  :       0.411                Log likelihood        :   -3002.887
# Sigma-square ML     :       0.169                Akaike info criterion :    6023.773
# S.E of regression ML:      0.4108                Schwarz criterion     :    6083.564
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       7.8497115       0.0154133     509.2807832       0.0000000
#                rooms      -0.0043571       0.0049975      -0.8718518       0.3833262
#                floor       0.0242083       0.0021420      11.3016433       0.0000000
#     needs_renovating      -0.0836825       0.0173037      -4.8361095       0.0000014
#               garden       0.0405178       0.0148883       2.7214435       0.0065196
#              terrace      -0.1137105       0.0112545     -10.1035939       0.0000000
#              new_dev       0.0831581       0.0489991       1.6971349       0.0897261
#               garage       0.1593033       0.0139263      11.4390642       0.0000000
#             w_garden      -0.0245924       0.0085279      -2.8837679       0.0039443
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            7.975
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2           0.504           0.7774
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                8         322.562           0.0000
# Koenker-Bassett test              8         315.900           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Lagrange Multiplier (lag)         1        3265.456           0.0000
# Robust LM (lag)                   1          51.560           0.0000
# Lagrange Multiplier (error)       1        3236.383           0.0000
# Robust LM (error)                 1          22.487           0.0000
# Lagrange Multiplier (SARMA)       2        3287.943           0.0000
#
# ================================ END OF REPORT =====================================

# %%
varis = ['pricems', 'floor', 'needs_renovating', 'garden', 'terrace',  'garage']

zona = db[(db["share_loc"] == 1)].drop_duplicates(subset=["lat", "lon"] )
y = np.log(zona['pricems'])
yxs = zona.loc[:, varis + ['pricems']].dropna()
w_garden = ps.knnW_from_array(zona.loc[\
                               yxs.index, \
                              ['lon', 'lat']\
                              ].values)
yxs_w = yxs.assign(w_garden=ps.lag_spatial(w_garden, yxs['garden'].values))

m2 = ps.spreg.OLS(y.values[:, None], \
                  yxs_w.drop('pricems', axis=1).values, \
                  w=w, spat_diag=True, \
                  name_x=yxs_w.drop('pricems', axis=1).columns.tolist(), name_y='ln(pricems)', name_ds = 'madrid')
print(m2.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :      madrid
# Weights matrix      :     unknown
# Dependent Variable  : ln(pricems)                Number of Observations:        5673
# Mean dependent var  :      7.9001                Number of Variables   :           7
# S.D. dependent var  :      0.4282                Degrees of Freedom    :        5666
# R-squared           :      0.0789
# Adjusted R-squared  :      0.0779
# Sum squared residual:     958.038                F-statistic           :     80.9036
# Sigma-square        :       0.169                Prob(F-statistic)     :   1.848e-97
# S.E. of regression  :       0.411                Log likelihood        :   -3004.679
# Sigma-square ML     :       0.169                Akaike info criterion :    6023.359
# S.E of regression ML:      0.4109                Schwarz criterion     :    6069.863
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       7.8404637       0.0104618     749.4385468       0.0000000
#                floor       0.0239493       0.0021330      11.2280049       0.0000000
#     needs_renovating      -0.0879444       0.0168567      -5.2171819       0.0000002
#               garden       0.0401072       0.0148885       2.6938310       0.0070844
#              terrace      -0.1150939       0.0110827     -10.3849856       0.0000000
#               garage       0.1598801       0.0138946      11.5066385       0.0000000
#             w_garden      -0.0241346       0.0085235      -2.8315416       0.0046488
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            4.436
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2           0.692           0.7075
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                6         316.095           0.0000
# Koenker-Bassett test              6         307.891           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Lagrange Multiplier (lag)         1        3256.090           0.0000
# Robust LM (lag)                   1          56.273           0.0000
# Lagrange Multiplier (error)       1        3218.704           0.0000
# Robust LM (error)                 1          18.887           0.0000
# Lagrange Multiplier (SARMA)       2        3274.977           0.0000
#
# ================================ END OF REPORT =====================================
